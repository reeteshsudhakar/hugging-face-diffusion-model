# %%
# !pip install diffusers transformers
# Out:
# Collecting diffusers
#   Downloading diffusers-0.1.3-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 3.1 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.21.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 24.7 MB/s eta 0:00:0000:0100:01
# Collecting Pillow
#   Downloading Pillow-9.2.0-cp39-cp39-macosx_11_0_arm64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 35.5 MB/s eta 0:00:0000:0100:01
# Collecting requests
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting filelock
#   Using cached filelock-3.7.1-py3-none-any.whl (10 kB)
# Collecting torch>=1.4
#   Using cached torch-1.12.0-cp39-none-macosx_11_0_arm64.whl (48.9 MB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Collecting numpy
#   Downloading numpy-1.23.1-cp39-cp39-macosx_11_0_arm64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 38.8 MB/s eta 0:00:0000:0100:01
# Collecting regex!=2019.12.17
#   Downloading regex-2022.7.25-cp39-cp39-macosx_11_0_arm64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 10.4 MB/s eta 0:00:00
# Collecting huggingface-hub
#   Using cached huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Using cached tokenizers-0.12.1-cp39-cp39-macosx_12_0_arm64.whl
# Collecting tqdm>=4.27
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/reeteshsudhakar/opt/anaconda3/envs/hugging-face-diffusion-model/lib/python3.9/site-packages (from transformers) (21.3)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0-cp39-cp39-macosx_11_0_arm64.whl (173 kB)
# Collecting typing-extensions>=3.7.4.3
#   Using cached typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/reeteshsudhakar/opt/anaconda3/envs/hugging-face-diffusion-model/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.11-py2.py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 6.0 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/reeteshsudhakar/opt/anaconda3/envs/hugging-face-diffusion-model/lib/python3.9/site-packages (from requests->diffusers) (2022.6.15)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Installing collected packages: tokenizers, zipp, urllib3, typing-extensions, tqdm, regex, pyyaml, Pillow, numpy, idna, filelock, charset-normalizer, torch, requests, importlib-metadata, huggingface-hub, transformers, diffusers
# Successfully installed Pillow-9.2.0 charset-normalizer-2.1.0 diffusers-0.1.3 filelock-3.7.1 huggingface-hub-0.8.1 idna-3.3 importlib-metadata-4.12.0 numpy-1.23.1 pyyaml-6.0 regex-2022.7.25 requests-2.28.1 tokenizers-0.12.1 torch-1.12.0 tqdm-4.64.0 transformers-4.21.0 typing-extensions-4.3.0 urllib3-1.26.11 zipp-3.8.1

# %%
from diffusers import DiffusionPipeline

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.5.2-cp39-cp39-macosx_11_0_arm64.whl (7.2 MB)
# Requirement already satisfied: packaging>=20.0 in /Users/reeteshsudhakar/opt/anaconda3/envs/hugging-face-diffusion-model/lib/python3.9/site-packages (from matplotlib) (21.3)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.34.4-py3-none-any.whl (944 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.1/944.1 kB 16.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: pillow>=6.2.0 in /Users/reeteshsudhakar/opt/anaconda3/envs/hugging-face-diffusion-model/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: numpy>=1.17 in /Users/reeteshsudhakar/opt/anaconda3/envs/hugging-face-diffusion-model/lib/python3.9/site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/reeteshsudhakar/opt/anaconda3/envs/hugging-face-diffusion-model/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp39-cp39-macosx_11_0_arm64.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 kB 2.6 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/reeteshsudhakar/opt/anaconda3/envs/hugging-face-diffusion-model/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in /Users/reeteshsudhakar/opt/anaconda3/envs/hugging-face-diffusion-model/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.34.4 kiwisolver-1.4.4 matplotlib-3.5.2

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
model_id = "CompVis/ldm-text2im-large-256"

# load model and scheduler
ldm = DiffusionPipeline.from_pretrained(model_id)
# Out:
# Downloading: 100%|██████████| 1.17k/1.17k [00:00<00:00, 324kB/s]
# Downloading: 100%|██████████| 2.96k/2.96k [00:00<00:00, 2.34MB/s]
# Downloading: 100%|██████████| 662/662 [00:00<00:00, 413kB/s]
# Downloading: 100%|██████████| 2.33G/2.33G [01:03<00:00, 36.7MB/s]
# Downloading: 100%|██████████| 118k/118k [00:00<00:00, 474kB/s]
# Downloading: 100%|██████████| 108k/108k [00:00<00:00, 413kB/s]
# Downloading: 100%|██████████| 98.2k/98.2k [00:00<00:00, 582kB/s]
# Downloading: 100%|██████████| 80.8k/80.8k [00:00<00:00, 984kB/s]
# Downloading: 100%|██████████| 376/376 [00:00<00:00, 82.9kB/s]
# Downloading: 100%|██████████| 252/252 [00:00<00:00, 79.2kB/s]
# Downloading: 100%|██████████| 125/125 [00:00<00:00, 106kB/s]
# Downloading: 100%|██████████| 420/420 [00:00<00:00, 112kB/s]
# Downloading: 100%|██████████| 232k/232k [00:00<00:00, 668kB/s]
# Downloading: 100%|██████████| 713/713 [00:00<00:00, 163kB/s]
# Downloading: 100%|██████████| 3.49G/3.49G [04:14<00:00, 13.7MB/s]
# Downloading: 100%|██████████| 522/522 [00:00<00:00, 133kB/s]
# Downloading: 100%|██████████| 335M/335M [00:08<00:00, 41.4MB/s]
# 100%|██████████| 50/50 [01:18<00:00,  1.57s/it]

# %%
# run pipeline in inference (sample random noise and denoise)
prompt = "A painting of a squirrel eating a burger"
images = ldm([prompt], num_inference_steps=50, eta=0.3, guidance_scale=6)["sample"]
plt.imshow(images[0])
# Out:
# 100%|██████████| 50/50 [01:18<00:00,  1.58s/it]
